# %% [markdown]
# ## Lab | API wrappers - Create your collection of songs & audio features
#
# #### Instructions
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
# !pip3 install spotipy
# !pip3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spotipy in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (2.19.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (from spotipy) (1.26.8)
# Requirement already satisfied: six>=1.15.0 in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Pablofuster/Library/Python/3.9/lib/python/site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# ERROR: unknown command "yellowbrick"

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.pipeline import Pipeline

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="183e423da2a54151a0129f003513a648",
                                                           client_secret="1a581c20e6d54804bd4e58b89da9c289"))
results = sp.search(q='artist:Ters', limit=1, type='track')
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3ATers&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Mf1s6zvBdwT3ZmEfWVovB'},
#        'href': 'https://api.spotify.com/v1/artists/5Mf1s6zvBdwT3ZmEfWVovB',
#        'id': '5Mf1s6zvBdwT3ZmEfWVovB',
#        'name': 'Ters',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Mf1s6zvBdwT3ZmEfWVovB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1QmQBiCDl3rT9jWWHxvBtX'},
#      'href': 'https://api.spotify.com/v1/albums/1QmQBiCDl3rT9jWWHxvBtX',
#      'id': '1QmQBiCDl3rT9jWWHxvBtX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27378e7dd6e00944f1bbd2fecf0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0278e7dd6e00944f1bbd2fecf0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485178e7dd6e00944f1bbd2fecf0',
#        'width': 64}],
#      'name': 'Nightmare',
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1QmQBiCDl3rT9jWWHxvBtX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Mf1s6zvBdwT3ZmEfWVovB'},
#       'href': 'https://api.spotify.com/v1/artists/5Mf1s6zvBdwT3ZmEfWVovB',
#       'id': '5Mf1s6zvBdwT3ZmEfWVovB',
#       'name': 'Ters',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Mf1s6zvBdwT3ZmEfWVovB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 132880,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHZ52066349'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6JfcSwhefvlhjjcYRGDpQu'},
#     'href': 'https://api.spotify.com/v1/tracks/6JfcSwhefvlhjjcYRGDpQu',
#     'id': '6JfcSwhefvlhjjcYRGDpQu',
#     'is_local': False,
#     'name': 'Nightmare',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c1613f7882c17f57f6dc5b97689e27f51dc2abae?cid=183e423da2a54151a0129f003513a648',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6JfcSwhefvlhjjcYRGDpQu'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=artist%3ATers&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 690}}

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DWZ5kgu17cbcC")
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ5kgu17cbcC/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IJJSEnYTWNaL8Ezk6yzAE'},
#        'href': 'https://api.spotify.com/v1/artists/2IJJSEnYTWNaL8Ezk6yzAE',
#        'id': '2IJJSEnYTWNaL8Ezk6yzAE',
#        'name': "Satan's Rats",
#        'type': 'artist',
#        'uri': 'spotify:artist:2IJJSEnYTWNaL8Ezk6yzAE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3IXIcAG1js5iPhTS4JBOdC'},
#      'href': 'https://api.spotify.com/v1/albums/3IXIcAG1js5iPhTS4JBOdC',
#      'id': '3IXIcAG1js5iPhTS4JBOdC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389dced4670ba8fe6fb601ff0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289dced4670ba8fe6fb601ff0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189dced4670ba8fe6fb601ff0',
#        'width': 64}],
#      'name': 'What A Bunch Of Rodents',
#      'release_date': '1977',
#      'release_date_precision': 'year',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3IXIcAG1js5iPhTS4JBOdC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IJJSEnYTWNaL8Ezk6yzAE'},
#       'href': 'https://api.spotify.com/v1/artists/2IJJSEnYTWNaL8Ezk6yzAE',
#       'id': '2IJJSEnYTWNaL8Ezk6yzAE',
#       'name': "Satan's Rats",
#       'type': 'artist',
#       'uri': 'spotify:artist:2IJJSEnYTWNaL8Ezk6yzAE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 129400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBNU0600005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2o1rN5QhKveneGrlBZiMYu'},
#     'href': 'https://api.spotify.com/v1/tracks/2o1rN5QhKveneGrlBZiMYu',
#     'id': '2o1rN5QhKveneGrlBZiMYu',
#     'is_local': False,
#     'name': 'You Make Me Sick',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6c9a54e8fe8f6e63e781881065d0f5f866e55128?cid=183e423da2a54151a0129f003513a648',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2o1rN5QhKveneGrlBZiMYu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0zwPBH9v7TUk4xfrZbS4nC'},
#        'href': 'https://api.spotify.com/v1/artists/0zwPBH9v7TUk4xfrZbS4nC',
#        'id': '0zwPBH9v7TUk4xfrZbS4nC',
#        'name': 'Otis Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:0zwPBH9v7TUk4xfrZbS4nC'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0sNUnuhlfzDbpJUcr7QduJ'},
#      'href': 'https://api.spotify.com/v1/albums/0sNUnuhlfzDbpJUcr7QduJ',
#      'id': '0sNUnuhlfzDbpJUcr7QduJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf32b1d920b2f83dd8594b85',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf32b1d920b2f83dd8594b85',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf32b1d920b2f83dd8594b85',
#        'width': 64}],
#      'name': 'Southside Chicago',
#      'release_date': '2018-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0sNUnuhlfzDbpJUcr7QduJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0zwPBH9v7TUk4xfrZbS4nC'},
#       'href': 'https://api.spotify.com/v1/artists/0zwPBH9v7TUk4xfrZbS4nC',
#       'id': '0zwPBH9v7TUk4xfrZbS4nC',
#       'name': 'Otis Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:0zwPBH9v7TUk4xfrZbS4nC'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 165893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCW61826505'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2kdW74hWl4csLzEptAB279'},
#     'href': 'https://api.spotify.com/v1/tracks/2kdW74hWl4csLzEptAB279',
#     'id': '2kdW74hWl4csLzEptAB279',
#     'is_local': False,
#     'name': 'Somebody Help Me',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2kdW74hWl4csLzEptAB279'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#        'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#        'id': '08GQAI4eElDnROBrJRGE0X',
#        'name': 'Fleetwood Mac',
#        'type': 'artist',
#        'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BwWUstDMUbgq2NYONRqlu'},
#      'href': 'https://api.spotify.com/v1/albums/0BwWUstDMUbgq2NYONRqlu',
#      'id': '0BwWUstDMUbgq2NYONRqlu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e52a59a28efa4773dd2bfe1b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e52a59a28efa4773dd2bfe1b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e52a59a28efa4773dd2bfe1b',
#        'width': 64}],
#      'name': 'Rumours (Super Deluxe)',
#      'release_date': '1977-02-04',
#      'release_date_precision': 'day',
#      'total_tracks': 58,
#      'type': 'album',
#      'uri': 'spotify:album:0BwWUstDMUbgq2NYONRqlu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#       'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#       'id': '08GQAI4eElDnROBrJRGE0X',
#       'name': 'Fleetwood Mac',
#       'type': 'artist',
#       'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 257800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11301111'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ofHAoxe9vBkTCp2UQIavz'},
#     'href': 'https://api.spotify.com/v1/tracks/0ofHAoxe9vBkTCp2UQIavz',
#     'id': '0ofHAoxe9vBkTCp2UQIavz',
#     'is_local': False,
#     'name': 'Dreams - 2004 Remaster',
#     'popularity': 87,
#     'preview_url': 'https://p.scdn.co/mp3-preview/40d1f6d82f16b05b62aae47e8e130de04b407fc8?cid=183e423da2a54151a0129f003513a648',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0ofHAoxe9vBkTCp2UQIavz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EF5vIcCYKMM61oYOG2Tqa'},
#        'href': 'https://api.spotify.com/v1/artists/4EF5vIcCYKMM61oYOG2Tqa',
#        'id': '4EF5vIcCYKMM61oYOG2Tqa',
#        'name': 'ESG',
#        'type': 'artist',
#        'uri': 'spotify:artist:4EF5vIcCYKMM61oYOG2Tqa'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6dE2iUELxsrVckRQqm8l1k'},
#      'href': 'https://api.spotify.com/v1/albums/6dE2iUELxsrVckRQqm8l1k',
#      'id': '6dE2iUELxsrVckRQqm8l1k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e52964b2b1e9469c9fd8ecf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e52964b2b1e9469c9fd8ecf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e52964b2b1e9469c9fd8ecf',
#        'width': 64}],
#      'name': 'Come Away With Esg',
#      'release_date': '1983',
#      'release_date_precision': 'year',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6dE2iUELxsrVckRQqm8l1k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EF5vIcCYKMM61oYOG2Tqa'},
#       'href': 'https://api.spotify.com/v1/artists/4EF5vIcCYKMM61oYOG2Tqa',
#       'id': '4EF5vIcCYKMM61oYOG2Tqa',
#       'name': 'ESG',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EF5vIcCYKMM61oYOG2Tqa'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 174866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCKK1014011'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MuMGHlG7XlKirwnjYGWLh'},
#     'href': 'https://api.spotify.com/v1/tracks/7MuMGHlG7XlKirwnjYGWLh',
#     'id': '7MuMGHlG7XlKirwnjYGWLh',
#     'is_local': False,
#     'name': 'My Love for You',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7MuMGHlG7XlKirwnjYGWLh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-19T17:37:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0zXA2xmkw5x4iN4Cb3j13P'},
#      'href': 'https://api.spotify.com/v1/albums/0zXA2xmkw5x4iN4Cb3j13P',
#      'id': '0zXA2xmkw5x4iN4Cb3j13P',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273312f95c11643417f3633c487',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02312f95c11643417f3633c487',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851312f95c11643417f3633c487',
#        'width': 64}],
#      'name': 'High Fidelity (Original Soundtrack)',
#      'release_date': '2020-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0zXA2xmkw5x4iN4Cb3j13P'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4QS6MMKct3F3LkN7cr6vHg'},
#       'href': 'https://api.spotify.com/v1/artists/4QS6MMKct3F3LkN7cr6vHg',
#       'id': '4QS6MMKct3F3LkN7cr6vHg',
#       'name': 'Thomas Doherty',
#       'type': 'artist',
#       'uri': 'spotify:artist:4QS6MMKct3F3LkN7cr6vHg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 186521,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR11939569'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3w190QG6aB6I0uGlVI5zG5'},
#     'href': 'https://api.spotify.com/v1/tracks/3w190QG6aB6I0uGlVI5zG5',
#     'id': '3w190QG6aB6I0uGlVI5zG5',
#     'is_local': False,
#     'name': 'Till It Hits the Ground',
#     'popularity': 40,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3w190QG6aB6I0uGlVI5zG5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nRXKDoWJ0J7xnYcFf6frY'},
#        'href': 'https://api.spotify.com/v1/artists/4nRXKDoWJ0J7xnYcFf6frY',
#        'id': '4nRXKDoWJ0J7xnYcFf6frY',
#        'name': 'The Makers',
#        'type': 'artist',
#        'uri': 'spotify:artist:4nRXKDoWJ0J7xnYcFf6frY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/11QMt8AngDuJpmAstNdigK'},
#      'href': 'https://api.spotify.com/v1/albums/11QMt8AngDuJpmAstNdigK',
#      'id': '11QMt8AngDuJpmAstNdigK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27319ad03037c28839c11cef44e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0219ad03037c28839c11cef44e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485119ad03037c28839c11cef44e',
#        'width': 64}],
#      'name': 'Howl',
#      'release_date': '1993-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:11QMt8AngDuJpmAstNdigK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nRXKDoWJ0J7xnYcFf6frY'},
#       'href': 'https://api.spotify.com/v1/artists/4nRXKDoWJ0J7xnYcFf6frY',
#       'id': '4nRXKDoWJ0J7xnYcFf6frY',
#       'name': 'The Makers',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nRXKDoWJ0J7xnYcFf6frY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 133133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFST9321201'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34lXzclvRDF7O8Xx0jAnFe'},
#     'href': 'https://api.spotify.com/v1/tracks/34lXzclvRDF7O8Xx0jAnFe',
#     'id': '34lXzclvRDF7O8Xx0jAnFe',
#     'is_local': False,
#     'name': 'I Just Might Crack',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/72c54f586b0dd5e604e76428cb5eff573cac117d?cid=183e423da2a54151a0129f003513a648',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:34lXzclvRDF7O8Xx0jAnFe'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ra4GIOgCZQZMOaUECftGN'},
#        'href': 'https://api.spotify.com/v1/artists/6ra4GIOgCZQZMOaUECftGN',
#        'id': '6ra4GIOgCZQZMOaUECftGN',
#        'name': 'Frank Zappa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6ra4GIOgCZQZMOaUECftGN'}],
#      'available_markets': ['AD',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KZ',
#       'LA',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hBKoHOpEvQ6g4CQFsEAdU'},
#      'href': 'https://api.spotify.com/v1/albums/4hBKoHOpEvQ6g4CQFsEAdU',
#      'id': '4hBKoHOpEvQ6g4CQFsEAdU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273885d9d53e458006a99de2642',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02885d9d53e458006a99de2642',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851885d9d53e458006a99de2642',
#        'width': 64}],
#      'name': 'Sheik Yerbouti',
#      'release_date': '1979-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:4hBKoHOpEvQ6g4CQFsEAdU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ra4GIOgCZQZMOaUECftGN'},
#       'href': 'https://api.spotify.com/v1/artists/6ra4GIOgCZQZMOaUECftGN',
#       'id': '6ra4GIOgCZQZMOaUECftGN',
#       'name': 'Frank Zappa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ra4GIOgCZQZMOaUECftGN'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KZ',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 169066,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USZPE1200245'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4tSTpnw8UYNlroCEo774tm'},
#     'href': 'https://api.spotify.com/v1/tracks/4tSTpnw8UYNlroCEo774tm',
#     'id': '4tSTpnw8UYNlroCEo774tm',
#     'is_local': False,
#     'name': 'Bobby Brown Goes Down',
#     'popularity': 63,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4tSTpnw8UYNlroCEo774tm'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sD7Cf3SaTVcrg81GQi1Xk'},
#        'href': 'https://api.spotify.com/v1/artists/5sD7Cf3SaTVcrg81GQi1Xk',
#        'id': '5sD7Cf3SaTVcrg81GQi1Xk',
#        'name': 'Piero Umiliani',
#        'type': 'artist',
#        'uri': 'spotify:artist:5sD7Cf3SaTVcrg81GQi1Xk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3j4peilVrbOhAZEIvA3ptr'},
#      'href': 'https://api.spotify.com/v1/albums/3j4peilVrbOhAZEIvA3ptr',
#      'id': '3j4peilVrbOhAZEIvA3ptr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d23f3cd05795137a95dc9db7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d23f3cd05795137a95dc9db7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d23f3cd05795137a95dc9db7',
#        'width': 64}],
#      'name': 'La Legge Dei Gangsters',
#      'release_date': '2009-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:3j4peilVrbOhAZEIvA3ptr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sD7Cf3SaTVcrg81GQi1Xk'},
#       'href': 'https://api.spotify.com/v1/artists/5sD7Cf3SaTVcrg81GQi1Xk',
#       'id': '5sD7Cf3SaTVcrg81GQi1Xk',
#       'name': 'Piero Umiliani',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sD7Cf3SaTVcrg81GQi1Xk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 154853,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITH750900118'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7CwBlDpfPEpeAmAO2fE1Ao'},
#     'href': 'https://api.spotify.com/v1/tracks/7CwBlDpfPEpeAmAO2fE1Ao',
#     'id': '7CwBlDpfPEpeAmAO2fE1Ao',
#     'is_local': False,
#     'name': 'Lui E Lei',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b04a69654c6e6230760c45d4a37dd8fc9cbc34d7?cid=183e423da2a54151a0129f003513a648',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:7CwBlDpfPEpeAmAO2fE1Ao'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QRAtOF6eGvcMXZR4fGuWn'},
#        'href': 'https://api.spotify.com/v1/artists/3QRAtOF6eGvcMXZR4fGuWn',
#        'id': '3QRAtOF6eGvcMXZR4fGuWn',
#        'name': 'Radio Stars',
#        'type': 'artist',
#        'uri': 'spotify:artist:3QRAtOF6eGvcMXZR4fGuWn'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4kg5sHfmmo1zEscpJdR9BA'},
#      'href': 'https://api.spotify.com/v1/albums/4kg5sHfmmo1zEscpJdR9BA',
#      'id': '4kg5sHfmmo1zEscpJdR9BA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739e7ef65a5b190f7173ac4de2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029e7ef65a5b190f7173ac4de2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519e7ef65a5b190f7173ac4de2',
#        'width': 64}],
#      'name': 'Holiday Album',
#      'release_date': '1978',
#      'release_date_precision': 'year',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4kg5sHfmmo1zEscpJdR9BA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QRAtOF6eGvcMXZR4fGuWn'},
#       'href': 'https://api.spotify.com/v1/artists/3QRAtOF6eGvcMXZR4fGuWn',
#       'id': '3QRAtOF6eGvcMXZR4fGuWn',
#       'name': 'Radio Stars',
#       'type': 'artist',
#       'uri': 'spotify:artist:3QRAtOF6eGvcMXZR4fGuWn'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 199873,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBHN9200680'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/13fd1R9kbhKzRFY6IVLtav'},
#     'href': 'https://api.spotify.com/v1/tracks/13fd1R9kbhKzRFY6IVLtav',
#     'id': '13fd1R9kbhKzRFY6IVLtav',
#     'is_local': False,
#     'name': 'The Real Me',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:13fd1R9kbhKzRFY6IVLtav'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sCJq0aWIAWwGsNujLLnYV'},
#        'href': 'https://api.spotify.com/v1/artists/0sCJq0aWIAWwGsNujLLnYV',
#        'id': '0sCJq0aWIAWwGsNujLLnYV',
#        'name': 'Lena Platonos',
#        'type': 'artist',
#        'uri': 'spotify:artist:0sCJq0aWIAWwGsNujLLnYV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3pTWwaomgSxu3Ncu8MWhfG'},
#      'href': 'https://api.spotify.com/v1/albums/3pTWwaomgSxu3Ncu8MWhfG',
#      'id': '3pTWwaomgSxu3Ncu8MWhfG',
# ...
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 456866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAC229800163'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5EQzuYfTZt7B2LqlvTF49l'},
#     'href': 'https://api.spotify.com/v1/tracks/5EQzuYfTZt7B2LqlvTF49l',
#     'id': '5EQzuYfTZt7B2LqlvTF49l',
#     'is_local': False,
#     'name': "It's All Coming Back to Me Now",
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1b3a534372cfb0e5866989c38d2b473041514d3d?cid=183e423da2a54151a0129f003513a648',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5EQzuYfTZt7B2LqlvTF49l'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX'},
#        'href': 'https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX',
#        'id': '5C0gCCG8N5Dh5dZytIgzLX',
#        'name': 'Os Mutantes',
#        'type': 'artist',
#        'uri': 'spotify:artist:5C0gCCG8N5Dh5dZytIgzLX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GN',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'ME',
#       'MK',
#       'MU',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TJ',
#       'TN',
#       'TR',
#       'TW',
#       'TZ',
#       'UA',
#       'US',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0RBkIFbQy91qv8Tqja20og'},
#      'href': 'https://api.spotify.com/v1/albums/0RBkIFbQy91qv8Tqja20og',
#      'id': '0RBkIFbQy91qv8Tqja20og',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cf5f9eaa0d3a164305c35b49',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cf5f9eaa0d3a164305c35b49',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cf5f9eaa0d3a164305c35b49',
#        'width': 64}],
#      'name': '"Os Mutantes"',
#      'release_date': '1968-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0RBkIFbQy91qv8Tqja20og'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX'},
#       'href': 'https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX',
#       'id': '5C0gCCG8N5Dh5dZytIgzLX',
#       'name': 'Os Mutantes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5C0gCCG8N5Dh5dZytIgzLX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GN',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MU',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TJ',
#      'TN',
#      'TR',
#      'TW',
#      'TZ',
#      'UA',
#      'US',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 219613,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BRPGD6800018'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Ika1afPnLLHTvuSHKGY02'},
#     'href': 'https://api.spotify.com/v1/tracks/3Ika1afPnLLHTvuSHKGY02',
#     'id': '3Ika1afPnLLHTvuSHKGY02',
#     'is_local': False,
#     'name': 'Le Premier Bonheur Du Jour',
#     'popularity': 40,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3Ika1afPnLLHTvuSHKGY02'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LB8qB5BPb3MHQrfkvifXU'},
#        'href': 'https://api.spotify.com/v1/artists/1LB8qB5BPb3MHQrfkvifXU',
#        'id': '1LB8qB5BPb3MHQrfkvifXU',
#        'name': 'Cheap Trick',
#        'type': 'artist',
#        'uri': 'spotify:artist:1LB8qB5BPb3MHQrfkvifXU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2sXJQdHykPYcRQ7xFhwzMR'},
#      'href': 'https://api.spotify.com/v1/albums/2sXJQdHykPYcRQ7xFhwzMR',
#      'id': '2sXJQdHykPYcRQ7xFhwzMR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27357a0bca6d7da93cd0c551f6a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0257a0bca6d7da93cd0c551f6a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485157a0bca6d7da93cd0c551f6a',
#        'width': 64}],
#      'name': 'In Color',
#      'release_date': '1977-09',
#      'release_date_precision': 'month',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2sXJQdHykPYcRQ7xFhwzMR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LB8qB5BPb3MHQrfkvifXU'},
#       'href': 'https://api.spotify.com/v1/artists/1LB8qB5BPb3MHQrfkvifXU',
#       'id': '1LB8qB5BPb3MHQrfkvifXU',
#       'name': 'Cheap Trick',
#       'type': 'artist',
#       'uri': 'spotify:artist:1LB8qB5BPb3MHQrfkvifXU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 191226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19802522'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1JkZg3eMQTmTn93E8Yd3UL'},
#     'href': 'https://api.spotify.com/v1/tracks/1JkZg3eMQTmTn93E8Yd3UL',
#     'id': '1JkZg3eMQTmTn93E8Yd3UL',
#     'is_local': False,
#     'name': 'I Want You to Want Me',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1c55371ac6dc7f4553e0f0ce75edf9b84d263ef1?cid=183e423da2a54151a0129f003513a648',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1JkZg3eMQTmTn93E8Yd3UL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-02-12T05:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aq8T2RcspxVOGgMrTzjWc'},
#        'href': 'https://api.spotify.com/v1/artists/6aq8T2RcspxVOGgMrTzjWc',
#        'id': '6aq8T2RcspxVOGgMrTzjWc',
#        'name': 'Soft Cell',
#        'type': 'artist',
#        'uri': 'spotify:artist:6aq8T2RcspxVOGgMrTzjWc'}],
#      'available_markets': ['CA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ZoEzhRK5UCqXqa3j62cK0'},
#      'href': 'https://api.spotify.com/v1/albums/1ZoEzhRK5UCqXqa3j62cK0',
#      'id': '1ZoEzhRK5UCqXqa3j62cK0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea8ba1b6208854b1103ec719',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea8ba1b6208854b1103ec719',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea8ba1b6208854b1103ec719',
#        'width': 64}],
#      'name': 'Non-Stop Ecstatic Dancing',
#      'release_date': '1981',
#      'release_date_precision': 'year',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:1ZoEzhRK5UCqXqa3j62cK0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aq8T2RcspxVOGgMrTzjWc'},
#       'href': 'https://api.spotify.com/v1/artists/6aq8T2RcspxVOGgMrTzjWc',
#       'id': '6aq8T2RcspxVOGgMrTzjWc',
#       'name': 'Soft Cell',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aq8T2RcspxVOGgMrTzjWc'}],
#     'available_markets': ['CA'],
#     'disc_number': 1,
#     'duration_ms': 320400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBF088200877'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1jYBgVBe93iKdvLcit7LIC'},
#     'href': 'https://api.spotify.com/v1/tracks/1jYBgVBe93iKdvLcit7LIC',
#     'id': '1jYBgVBe93iKdvLcit7LIC',
#     'is_local': False,
#     'name': 'Memorabilia',
#     'popularity': 10,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1jYBgVBe93iKdvLcit7LIC'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZ5kgu17cbcC/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 129}

# %%
playlist["total"]
# Out:
# 129

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "37i9dQZF1DWZ5kgu17cbcC")
tracks
# Out:
# [{'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IJJSEnYTWNaL8Ezk6yzAE'},
#       'href': 'https://api.spotify.com/v1/artists/2IJJSEnYTWNaL8Ezk6yzAE',
#       'id': '2IJJSEnYTWNaL8Ezk6yzAE',
#       'name': "Satan's Rats",
#       'type': 'artist',
#       'uri': 'spotify:artist:2IJJSEnYTWNaL8Ezk6yzAE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3IXIcAG1js5iPhTS4JBOdC'},
#     'href': 'https://api.spotify.com/v1/albums/3IXIcAG1js5iPhTS4JBOdC',
#     'id': '3IXIcAG1js5iPhTS4JBOdC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27389dced4670ba8fe6fb601ff0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0289dced4670ba8fe6fb601ff0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485189dced4670ba8fe6fb601ff0',
#       'width': 64}],
#     'name': 'What A Bunch Of Rodents',
#     'release_date': '1977',
#     'release_date_precision': 'year',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:3IXIcAG1js5iPhTS4JBOdC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IJJSEnYTWNaL8Ezk6yzAE'},
#      'href': 'https://api.spotify.com/v1/artists/2IJJSEnYTWNaL8Ezk6yzAE',
#      'id': '2IJJSEnYTWNaL8Ezk6yzAE',
#      'name': "Satan's Rats",
#      'type': 'artist',
#      'uri': 'spotify:artist:2IJJSEnYTWNaL8Ezk6yzAE'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 129400,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBNU0600005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2o1rN5QhKveneGrlBZiMYu'},
#    'href': 'https://api.spotify.com/v1/tracks/2o1rN5QhKveneGrlBZiMYu',
#    'id': '2o1rN5QhKveneGrlBZiMYu',
#    'is_local': False,
#    'name': 'You Make Me Sick',
#    'popularity': 40,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6c9a54e8fe8f6e63e781881065d0f5f866e55128?cid=183e423da2a54151a0129f003513a648',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2o1rN5QhKveneGrlBZiMYu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0zwPBH9v7TUk4xfrZbS4nC'},
#       'href': 'https://api.spotify.com/v1/artists/0zwPBH9v7TUk4xfrZbS4nC',
#       'id': '0zwPBH9v7TUk4xfrZbS4nC',
#       'name': 'Otis Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:0zwPBH9v7TUk4xfrZbS4nC'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0sNUnuhlfzDbpJUcr7QduJ'},
#     'href': 'https://api.spotify.com/v1/albums/0sNUnuhlfzDbpJUcr7QduJ',
#     'id': '0sNUnuhlfzDbpJUcr7QduJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf32b1d920b2f83dd8594b85',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf32b1d920b2f83dd8594b85',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf32b1d920b2f83dd8594b85',
#       'width': 64}],
#     'name': 'Southside Chicago',
#     'release_date': '2018-06-22',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:0sNUnuhlfzDbpJUcr7QduJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0zwPBH9v7TUk4xfrZbS4nC'},
#      'href': 'https://api.spotify.com/v1/artists/0zwPBH9v7TUk4xfrZbS4nC',
#      'id': '0zwPBH9v7TUk4xfrZbS4nC',
#      'name': 'Otis Brown',
#      'type': 'artist',
#      'uri': 'spotify:artist:0zwPBH9v7TUk4xfrZbS4nC'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 165893,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCW61826505'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2kdW74hWl4csLzEptAB279'},
#    'href': 'https://api.spotify.com/v1/tracks/2kdW74hWl4csLzEptAB279',
#    'id': '2kdW74hWl4csLzEptAB279',
#    'is_local': False,
#    'name': 'Somebody Help Me',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:2kdW74hWl4csLzEptAB279'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#       'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#       'id': '08GQAI4eElDnROBrJRGE0X',
#       'name': 'Fleetwood Mac',
#       'type': 'artist',
#       'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0BwWUstDMUbgq2NYONRqlu'},
#     'href': 'https://api.spotify.com/v1/albums/0BwWUstDMUbgq2NYONRqlu',
#     'id': '0BwWUstDMUbgq2NYONRqlu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e52a59a28efa4773dd2bfe1b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e52a59a28efa4773dd2bfe1b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e52a59a28efa4773dd2bfe1b',
#       'width': 64}],
#     'name': 'Rumours (Super Deluxe)',
#     'release_date': '1977-02-04',
#     'release_date_precision': 'day',
#     'total_tracks': 58,
#     'type': 'album',
#     'uri': 'spotify:album:0BwWUstDMUbgq2NYONRqlu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#      'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#      'id': '08GQAI4eElDnROBrJRGE0X',
#      'name': 'Fleetwood Mac',
#      'type': 'artist',
#      'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 257800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB11301111'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ofHAoxe9vBkTCp2UQIavz'},
#    'href': 'https://api.spotify.com/v1/tracks/0ofHAoxe9vBkTCp2UQIavz',
#    'id': '0ofHAoxe9vBkTCp2UQIavz',
#    'is_local': False,
#    'name': 'Dreams - 2004 Remaster',
#    'popularity': 87,
#    'preview_url': 'https://p.scdn.co/mp3-preview/40d1f6d82f16b05b62aae47e8e130de04b407fc8?cid=183e423da2a54151a0129f003513a648',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0ofHAoxe9vBkTCp2UQIavz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EF5vIcCYKMM61oYOG2Tqa'},
#       'href': 'https://api.spotify.com/v1/artists/4EF5vIcCYKMM61oYOG2Tqa',
#       'id': '4EF5vIcCYKMM61oYOG2Tqa',
#       'name': 'ESG',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EF5vIcCYKMM61oYOG2Tqa'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6dE2iUELxsrVckRQqm8l1k'},
#     'href': 'https://api.spotify.com/v1/albums/6dE2iUELxsrVckRQqm8l1k',
#     'id': '6dE2iUELxsrVckRQqm8l1k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735e52964b2b1e9469c9fd8ecf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025e52964b2b1e9469c9fd8ecf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515e52964b2b1e9469c9fd8ecf',
#       'width': 64}],
#     'name': 'Come Away With Esg',
#     'release_date': '1983',
#     'release_date_precision': 'year',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6dE2iUELxsrVckRQqm8l1k'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EF5vIcCYKMM61oYOG2Tqa'},
#      'href': 'https://api.spotify.com/v1/artists/4EF5vIcCYKMM61oYOG2Tqa',
#      'id': '4EF5vIcCYKMM61oYOG2Tqa',
#      'name': 'ESG',
#      'type': 'artist',
#      'uri': 'spotify:artist:4EF5vIcCYKMM61oYOG2Tqa'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 174866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCKK1014011'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7MuMGHlG7XlKirwnjYGWLh'},
#    'href': 'https://api.spotify.com/v1/tracks/7MuMGHlG7XlKirwnjYGWLh',
#    'id': '7MuMGHlG7XlKirwnjYGWLh',
#    'is_local': False,
#    'name': 'My Love for You',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:7MuMGHlG7XlKirwnjYGWLh'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-19T17:37:43Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0zXA2xmkw5x4iN4Cb3j13P'},
#     'href': 'https://api.spotify.com/v1/albums/0zXA2xmkw5x4iN4Cb3j13P',
#     'id': '0zXA2xmkw5x4iN4Cb3j13P',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273312f95c11643417f3633c487',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02312f95c11643417f3633c487',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851312f95c11643417f3633c487',
#       'width': 64}],
#     'name': 'High Fidelity (Original Soundtrack)',
#     'release_date': '2020-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0zXA2xmkw5x4iN4Cb3j13P'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4QS6MMKct3F3LkN7cr6vHg'},
#      'href': 'https://api.spotify.com/v1/artists/4QS6MMKct3F3LkN7cr6vHg',
#      'id': '4QS6MMKct3F3LkN7cr6vHg',
#      'name': 'Thomas Doherty',
#      'type': 'artist',
#      'uri': 'spotify:artist:4QS6MMKct3F3LkN7cr6vHg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 186521,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHR11939569'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3w190QG6aB6I0uGlVI5zG5'},
#    'href': 'https://api.spotify.com/v1/tracks/3w190QG6aB6I0uGlVI5zG5',
#    'id': '3w190QG6aB6I0uGlVI5zG5',
#    'is_local': False,
#    'name': 'Till It Hits the Ground',
#    'popularity': 40,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3w190QG6aB6I0uGlVI5zG5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nRXKDoWJ0J7xnYcFf6frY'},
#       'href': 'https://api.spotify.com/v1/artists/4nRXKDoWJ0J7xnYcFf6frY',
#       'id': '4nRXKDoWJ0J7xnYcFf6frY',
#       'name': 'The Makers',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nRXKDoWJ0J7xnYcFf6frY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/11QMt8AngDuJpmAstNdigK'},
#     'href': 'https://api.spotify.com/v1/albums/11QMt8AngDuJpmAstNdigK',
#     'id': '11QMt8AngDuJpmAstNdigK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27319ad03037c28839c11cef44e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0219ad03037c28839c11cef44e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485119ad03037c28839c11cef44e',
#       'width': 64}],
#     'name': 'Howl',
#     'release_date': '1993-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:11QMt8AngDuJpmAstNdigK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nRXKDoWJ0J7xnYcFf6frY'},
#      'href': 'https://api.spotify.com/v1/artists/4nRXKDoWJ0J7xnYcFf6frY',
#      'id': '4nRXKDoWJ0J7xnYcFf6frY',
#      'name': 'The Makers',
#      'type': 'artist',
#      'uri': 'spotify:artist:4nRXKDoWJ0J7xnYcFf6frY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 133133,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USFST9321201'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/34lXzclvRDF7O8Xx0jAnFe'},
#    'href': 'https://api.spotify.com/v1/tracks/34lXzclvRDF7O8Xx0jAnFe',
#    'id': '34lXzclvRDF7O8Xx0jAnFe',
#    'is_local': False,
#    'name': 'I Just Might Crack',
#    'popularity': 34,
#    'preview_url': 'https://p.scdn.co/mp3-preview/72c54f586b0dd5e604e76428cb5eff573cac117d?cid=183e423da2a54151a0129f003513a648',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:34lXzclvRDF7O8Xx0jAnFe'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ra4GIOgCZQZMOaUECftGN'},
#       'href': 'https://api.spotify.com/v1/artists/6ra4GIOgCZQZMOaUECftGN',
#       'id': '6ra4GIOgCZQZMOaUECftGN',
#       'name': 'Frank Zappa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ra4GIOgCZQZMOaUECftGN'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KZ',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hBKoHOpEvQ6g4CQFsEAdU'},
#     'href': 'https://api.spotify.com/v1/albums/4hBKoHOpEvQ6g4CQFsEAdU',
#     'id': '4hBKoHOpEvQ6g4CQFsEAdU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273885d9d53e458006a99de2642',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02885d9d53e458006a99de2642',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851885d9d53e458006a99de2642',
#       'width': 64}],
#     'name': 'Sheik Yerbouti',
#     'release_date': '1979-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:4hBKoHOpEvQ6g4CQFsEAdU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ra4GIOgCZQZMOaUECftGN'},
#      'href': 'https://api.spotify.com/v1/artists/6ra4GIOgCZQZMOaUECftGN',
#      'id': '6ra4GIOgCZQZMOaUECftGN',
#      'name': 'Frank Zappa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ra4GIOgCZQZMOaUECftGN'}],
#    'available_markets': ['AD',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KZ',
#     'LA',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PW',
#     'PY',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 169066,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USZPE1200245'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4tSTpnw8UYNlroCEo774tm'},
#    'href': 'https://api.spotify.com/v1/tracks/4tSTpnw8UYNlroCEo774tm',
#    'id': '4tSTpnw8UYNlroCEo774tm',
#    'is_local': False,
#    'name': 'Bobby Brown Goes Down',
#    'popularity': 63,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4tSTpnw8UYNlroCEo774tm'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sD7Cf3SaTVcrg81GQi1Xk'},
#       'href': 'https://api.spotify.com/v1/artists/5sD7Cf3SaTVcrg81GQi1Xk',
#       'id': '5sD7Cf3SaTVcrg81GQi1Xk',
#       'name': 'Piero Umiliani',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sD7Cf3SaTVcrg81GQi1Xk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3j4peilVrbOhAZEIvA3ptr'},
#     'href': 'https://api.spotify.com/v1/albums/3j4peilVrbOhAZEIvA3ptr',
#     'id': '3j4peilVrbOhAZEIvA3ptr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d23f3cd05795137a95dc9db7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d23f3cd05795137a95dc9db7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d23f3cd05795137a95dc9db7',
#       'width': 64}],
#     'name': 'La Legge Dei Gangsters',
#     'release_date': '2009-11-19',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:3j4peilVrbOhAZEIvA3ptr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sD7Cf3SaTVcrg81GQi1Xk'},
#      'href': 'https://api.spotify.com/v1/artists/5sD7Cf3SaTVcrg81GQi1Xk',
#      'id': '5sD7Cf3SaTVcrg81GQi1Xk',
#      'name': 'Piero Umiliani',
#      'type': 'artist',
#      'uri': 'spotify:artist:5sD7Cf3SaTVcrg81GQi1Xk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 154853,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'ITH750900118'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7CwBlDpfPEpeAmAO2fE1Ao'},
#    'href': 'https://api.spotify.com/v1/tracks/7CwBlDpfPEpeAmAO2fE1Ao',
#    'id': '7CwBlDpfPEpeAmAO2fE1Ao',
#    'is_local': False,
#    'name': 'Lui E Lei',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b04a69654c6e6230760c45d4a37dd8fc9cbc34d7?cid=183e423da2a54151a0129f003513a648',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:7CwBlDpfPEpeAmAO2fE1Ao'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QRAtOF6eGvcMXZR4fGuWn'},
#       'href': 'https://api.spotify.com/v1/artists/3QRAtOF6eGvcMXZR4fGuWn',
#       'id': '3QRAtOF6eGvcMXZR4fGuWn',
#       'name': 'Radio Stars',
#       'type': 'artist',
#       'uri': 'spotify:artist:3QRAtOF6eGvcMXZR4fGuWn'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kg5sHfmmo1zEscpJdR9BA'},
#     'href': 'https://api.spotify.com/v1/albums/4kg5sHfmmo1zEscpJdR9BA',
#     'id': '4kg5sHfmmo1zEscpJdR9BA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739e7ef65a5b190f7173ac4de2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029e7ef65a5b190f7173ac4de2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519e7ef65a5b190f7173ac4de2',
#       'width': 64}],
#     'name': 'Holiday Album',
#     'release_date': '1978',
#     'release_date_precision': 'year',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4kg5sHfmmo1zEscpJdR9BA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QRAtOF6eGvcMXZR4fGuWn'},
#      'href': 'https://api.spotify.com/v1/artists/3QRAtOF6eGvcMXZR4fGuWn',
#      'id': '3QRAtOF6eGvcMXZR4fGuWn',
#      'name': 'Radio Stars',
#      'type': 'artist',
#      'uri': 'spotify:artist:3QRAtOF6eGvcMXZR4fGuWn'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 199873,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBHN9200680'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/13fd1R9kbhKzRFY6IVLtav'},
#    'href': 'https://api.spotify.com/v1/tracks/13fd1R9kbhKzRFY6IVLtav',
#    'id': '13fd1R9kbhKzRFY6IVLtav',
#    'is_local': False,
#    'name': 'The Real Me',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:13fd1R9kbhKzRFY6IVLtav'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sCJq0aWIAWwGsNujLLnYV'},
#       'href': 'https://api.spotify.com/v1/artists/0sCJq0aWIAWwGsNujLLnYV',
#       'id': '0sCJq0aWIAWwGsNujLLnYV',
#       'name': 'Lena Platonos',
#       'type': 'artist',
#       'uri': 'spotify:artist:0sCJq0aWIAWwGsNujLLnYV'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3pTWwaomgSxu3Ncu8MWhfG'},
#     'href': 'https://api.spotify.com/v1/albums/3pTWwaomgSxu3Ncu8MWhfG',
#     'id': '3pTWwaomgSxu3Ncu8MWhfG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273725311b2d15556d17a1b06fb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02725311b2d15556d17a1b06fb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851725311b2d15556d17a1b06fb',
#       'width': 64}],
#     'name': 'Gallop',
#     'release_date': '2015-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3pTWwaomgSxu3Ncu8MWhfG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0sCJq0aWIAWwGsNujLLnYV'},
#      'href': 'https://api.spotify.com/v1/artists/0sCJq0aWIAWwGsNujLLnYV',
#      'id': '0sCJq0aWIAWwGsNujLLnYV',
#      'name': 'Lena Platonos',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sCJq0aWIAWwGsNujLLnYV'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 159153,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQY51728399'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Tr31cx6UnS63dGNh4JKXX'},
#    'href': 'https://api.spotify.com/v1/tracks/6Tr31cx6UnS63dGNh4JKXX',
#    'id': '6Tr31cx6UnS63dGNh4JKXX',
#    'is_local': False,
#    'name': 'And We Hear "I Love You"',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6Tr31cx6UnS63dGNh4JKXX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4QTVePrFu1xuGM9K0kNXkk'},
#       'href': 'https://api.spotify.com/v1/artists/4QTVePrFu1xuGM9K0kNXkk',
#       'id': '4QTVePrFu1xuGM9K0kNXkk',
#       'name': 'Dexys Midnight Runners',
#       'type': 'artist',
#       'uri': 'spotify:artist:4QTVePrFu1xuGM9K0kNXkk'}],
#     'available_markets': ['AE',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FR',
#      'GB',
#      'GN',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'ME',
#      'MK',
#      'MT',
#      'MU',
#      'MY',
#      'NG',
# ...
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:2TY5pohPtUqu1c5fy7pW0F'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30XB6UJMhn7v7ZDX2GlIsM'},
#      'href': 'https://api.spotify.com/v1/artists/30XB6UJMhn7v7ZDX2GlIsM',
#      'id': '30XB6UJMhn7v7ZDX2GlIsM',
#      'name': 'The Men',
#      'type': 'artist',
#      'uri': 'spotify:artist:30XB6UJMhn7v7ZDX2GlIsM'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 328929,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US5NR1410703'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3x2kMMjAMfZvgV9PacT3Mw'},
#    'href': 'https://api.spotify.com/v1/tracks/3x2kMMjAMfZvgV9PacT3Mw',
#    'id': '3x2kMMjAMfZvgV9PacT3Mw',
#    'is_local': False,
#    'name': 'Another Night',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3x2kMMjAMfZvgV9PacT3Mw'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ej6u8fvyHFFKn5GaQ5cPn'},
#       'href': 'https://api.spotify.com/v1/artists/6Ej6u8fvyHFFKn5GaQ5cPn',
#       'id': '6Ej6u8fvyHFFKn5GaQ5cPn',
#       'name': 'Ted Lucas',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ej6u8fvyHFFKn5GaQ5cPn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2CEQedK1AH7F8zcYM7o0Yd'},
#     'href': 'https://api.spotify.com/v1/albums/2CEQedK1AH7F8zcYM7o0Yd',
#     'id': '2CEQedK1AH7F8zcYM7o0Yd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734d7ebbd38408cbf54b3df4f6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024d7ebbd38408cbf54b3df4f6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514d7ebbd38408cbf54b3df4f6',
#       'width': 64}],
#     'name': 'Ted Lucas',
#     'release_date': '2018-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:2CEQedK1AH7F8zcYM7o0Yd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ej6u8fvyHFFKn5GaQ5cPn'},
#      'href': 'https://api.spotify.com/v1/artists/6Ej6u8fvyHFFKn5GaQ5cPn',
#      'id': '6Ej6u8fvyHFFKn5GaQ5cPn',
#      'name': 'Ted Lucas',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Ej6u8fvyHFFKn5GaQ5cPn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 152787,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'UST8K1851562'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1WJKoGIVHwYcgMcd1UJGl3'},
#    'href': 'https://api.spotify.com/v1/tracks/1WJKoGIVHwYcgMcd1UJGl3',
#    'id': '1WJKoGIVHwYcgMcd1UJGl3',
#    'is_local': False,
#    'name': 'Baby Where You Are',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f2b6e4107a118bd776ae270a012920b3ca38a3e5?cid=183e423da2a54151a0129f003513a648',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:1WJKoGIVHwYcgMcd1UJGl3'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1m5Ph9rM9DvGWyvopepCLA'},
#       'href': 'https://api.spotify.com/v1/artists/1m5Ph9rM9DvGWyvopepCLA',
#       'id': '1m5Ph9rM9DvGWyvopepCLA',
#       'name': 'Double Tiger',
#       'type': 'artist',
#       'uri': 'spotify:artist:1m5Ph9rM9DvGWyvopepCLA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7FfhJYPw3CG21a10BkLBY6'},
#     'href': 'https://api.spotify.com/v1/albums/7FfhJYPw3CG21a10BkLBY6',
#     'id': '7FfhJYPw3CG21a10BkLBY6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27356fd5532a12897a4dd6d6f36',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0256fd5532a12897a4dd6d6f36',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485156fd5532a12897a4dd6d6f36',
#       'width': 64}],
#     'name': 'Sharp & Ready',
#     'release_date': '2017-06-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:7FfhJYPw3CG21a10BkLBY6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1m5Ph9rM9DvGWyvopepCLA'},
#      'href': 'https://api.spotify.com/v1/artists/1m5Ph9rM9DvGWyvopepCLA',
#      'id': '1m5Ph9rM9DvGWyvopepCLA',
#      'name': 'Double Tiger',
#      'type': 'artist',
#      'uri': 'spotify:artist:1m5Ph9rM9DvGWyvopepCLA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 242158,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US4CL1710063'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2JjDHw5iXDqGZL0H4jpU58'},
#    'href': 'https://api.spotify.com/v1/tracks/2JjDHw5iXDqGZL0H4jpU58',
#    'id': '2JjDHw5iXDqGZL0H4jpU58',
#    'is_local': False,
#    'name': 'Ram Dancehall',
#    'popularity': 26,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5f09e06dc4d156af9bf9294e486e6e7b76310918?cid=183e423da2a54151a0129f003513a648',
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:2JjDHw5iXDqGZL0H4jpU58'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-02-12T05:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/450o9jw6AtiQlQkHCdH6Ru'},
#       'href': 'https://api.spotify.com/v1/artists/450o9jw6AtiQlQkHCdH6Ru',
#       'id': '450o9jw6AtiQlQkHCdH6Ru',
#       'name': 'Funkadelic',
#       'type': 'artist',
#       'uri': 'spotify:artist:450o9jw6AtiQlQkHCdH6Ru'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/32mkDUhwDI9JCnKLjm5RGw'},
#     'href': 'https://api.spotify.com/v1/albums/32mkDUhwDI9JCnKLjm5RGw',
#     'id': '32mkDUhwDI9JCnKLjm5RGw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27351e923158c6e1a549d0fb26f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0251e923158c6e1a549d0fb26f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485151e923158c6e1a549d0fb26f',
#       'width': 64}],
#     'name': 'Maggot Brain',
#     'release_date': '1971-07-12',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:32mkDUhwDI9JCnKLjm5RGw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/450o9jw6AtiQlQkHCdH6Ru'},
#      'href': 'https://api.spotify.com/v1/artists/450o9jw6AtiQlQkHCdH6Ru',
#      'id': '450o9jw6AtiQlQkHCdH6Ru',
#      'name': 'Funkadelic',
#      'type': 'artist',
#      'uri': 'spotify:artist:450o9jw6AtiQlQkHCdH6Ru'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 171560,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US25X0588948'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6QUngYwZ65et2ye7Bj85EK'},
#    'href': 'https://api.spotify.com/v1/tracks/6QUngYwZ65et2ye7Bj85EK',
#    'id': '6QUngYwZ65et2ye7Bj85EK',
#    'is_local': False,
#    'name': 'Can You Get To That',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6QUngYwZ65et2ye7Bj85EK'},
#   'video_thumbnail': {'url': None}}]

# %%
len(tracks)
# Out:
# 129

# %%
def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
def get_artists_ids_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists_ids = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])
            
    return list(set(artists_ids))

# %%
artists_high = get_artists_from_playlist("37i9dQZF1DWZ5kgu17cbcC")
artists_high
# Out:
# ['Radio Stars',
#  "Sinéad O'Connor",
#  'The Golden Filter',
#  'Omar Apollo',
#  "Satan's Rats",
#  'David Bowie',
#  'Kaleta & Super Yamba Band',
#  'Way Yes',
#  'Holy Ghost!',
#  'The Men',
#  'Tim and Foty',
#  'Raekwon',
#  'Ann Peebles',
#  'El Freaky',
#  'John Moods',
#  'Sun Ra',
#  'Los Tones',
#  'Rikki Ililonga',
#  'Durand Jones & The Indications',
#  'TEYMORI',
#  'Otis Brown',
#  'Piero Umiliani',
#  'Grapetooth',
#  'Mathis Hunter',
#  'Sonny Rollins',
#  'Yvonne Fair',
#  'Silk Rhodes',
#  'Dexter Lee Moore',
#  'Nick Drake',
#  'Lea Lea',
#  'Bad Brains',
#  'Empire ISIS',
#  'WITCH',
#  'Stiff Little Fingers',
#  'Nina Simone',
#  'Ptaf',
#  'Dillinger',
#  'Janet Jackson',
#  'De Lux',
#  'U-God',
#  'Serguei',
#  'Impala Syndrome',
#  'Manzanita y su Conjunto',
#  'Talking Heads',
#  'The Roots',
#  'Marvin Gaye',
#  'Sylvester',
#  'Blondie',
#  'Mavis John',
#  'Ghostface Killah',
#  'MUNYA',
#  'Heavy Trash',
#  'Ras Jahonnan',
#  'The Makers',
#  'Denise Darlington',
#  'Ebo Taylor',
#  'Ike & Tina Turner',
#  'Stevie Wonder',
#  'Ronnie Taylor',
#  'The Notorious B.I.G.',
#  'Jitwam',
#  'Kluentah',
#  '!!!',
#  'Bill Withers',
#  'Bosko',
#  'Clarence Murray',
#  'Geoffrey Landers',
#  'Betty Davis',
#  'The Beta Band',
#  'Swamp Dogg',
#  'William Onyeabor',
#  'Soft Cell',
#  'Cheap Trick',
#  'Darondo',
#  'Kantata',
#  'Aretha Franklin',
#  'Aura',
#  'A Tribe Called Quest',
#  'Gabriella Cohen',
#  'Beastie Boys',
#  'Sam Dees',
#  'Double Tiger',
#  'Circle Jerks',
#  'Reginald Omas Mamode IV',
#  'ESG',
#  'Luther Vandross',
#  'Fleetwood Mac',
#  'Cobra Man',
#  'Hailu Mergia',
#  'Os Mutantes',
#  'Jesus Wayne',
#  'Y La Bamba',
#  'Outkast',
#  'Death',
#  'The Equatics',
#  'Céline Dion',
#  'Funkadelic',
#  'World Brain',
#  'Dahlak Band',
#  'Ho99o9',
#  'Jimi Hendrix',
#  "Ronnie D'Addario",
#  'Kevin Rowland',
#  'Grateful Dead',
#  'Tariq Trotter',
#  'Minor Threat',
#  'Direct Drive',
#  'Dead Kennedys',
#  'Ted Lucas',
#  'Bango',
#  'The Pointer Sisters',
#  'Erykah Badu',
#  'Prince',
#  'GBH',
#  'Le1f',
#  'Boyz II Men',
#  'Barbara Stant',
#  'Frank Zappa',
#  'U.S. 69',
#  'Dexys Midnight Runners',
#  'Thomas Doherty',
#  'BOYTOY',
#  'Frank Ocean',
#  'Miho Hatori',
#  'The Replacements',
#  'Blackalicious',
#  'Eve',
#  'Minnie Riperton',
#  'Lula Côrtes',
#  'Lescop',
#  'Lena Platonos',
#  'Lynn Williams',
#  'Wings']

# %%
artist_O = get_artists_from_playlist('2X02jK3CNuNmB8xg7V01te')
artist_O
# Out:
# ['Wilson Pickett',
#  "Sinéad O'Connor",
#  'Journey',
#  'Sixpence None The Richer',
#  "Des'ree",
#  'LeAnn Rimes',
#  'Barry Manilow',
#  'Katrina & The Waves',
#  '4 Non Blondes',
#  'Rick Astley',
#  'Lou Reed',
#  'Donna Summer',
#  'The Temptations',
#  'Eagles',
#  'Depeche Mode',
#  'Foreigner',
#  'David Bowie',
#  'Survivor',
#  'Mc Miker "G" & Deejay Sven',
#  'Roy Orbison',
#  'Gabrielle',
#  'Etta James',
#  'Evanescence',
#  'America',
#  'Tammi Terrell',
#  'blink-182',
#  'Creedence Clearwater Revival',
#  'UB40',
#  'Dolly Parton',
#  'Björn Skifs',
#  'The Police',
#  'Heart',
#  'Bobby McFerrin',
#  'Christopher Cross',
#  'Otis Redding',
#  'Neil Diamond',
#  'The Spencer Davis Group',
#  'Percy Sledge',
#  'Daryl Hall & John Oates',
#  'Cheryl Lynn',
#  'Gwen Stefani',
#  'The Rembrandts',
#  'Backstreet Boys',
#  'Elton John',
#  'Tracy Chapman',
#  'Donny Hathaway',
#  'Jimmy Cliff',
#  'Ronan Keating',
#  'Commodores',
#  'Barry White',
#  'Texas',
#  'Elvin Bishop',
#  'Sam & Dave',
#  'Chicago',
#  'Jack Joseph Puig',
#  'MC Hammer',
#  'The Righteous Brothers',
#  'Solomon Burke',
#  'Van Morrison',
#  'Harry Nilsson',
#  'Paul Simon',
#  'The Isley Brothers',
#  'Cher',
#  'Whitney Houston',
#  'New Radicals',
#  'Nina Simone',
#  '3 Doors Down',
#  'Inner Circle',
#  'Billy Paul',
#  'Curtis Mayfield',
#  'Eminem',
#  'Scorpions',
#  'Bap Kennedy',
#  'Billy Joel',
#  'Akon',
#  'Boney M.',
#  'Four Tops',
#  'Air Supply',
#  'Berlin',
#  'Bobby Hebb',
#  'Rod Stewart',
#  'Marvin Gaye',
#  'Shania Twain',
#  'Sting',
#  "The O'Jays",
#  'Yazoo',
#  'Billie Holiday',
#  'The Five Stairsteps',
#  'Kiki Dee',
#  'Yusuf / Cat Stevens',
#  'Sam Cooke',
#  'Suzanne Vega',
#  'Louis Armstrong',
#  'Stevie Wonder',
#  'George Michael',
#  'Extreme',
#  'TLC',
#  'Philip Bailey',
#  'Phil Collins',
#  'Lionel Richie',
#  'Domenico Modugno',
#  'King Harvest',
#  'Paul McCartney',
#  'Counting Crows',
#  'Alphaville',
#  'Savage Garden',
#  'The Proclaimers',
#  'Fergie',
#  'The Spinners',
#  'Kim Carnes',
#  'The Jackson 5',
#  'The Supremes',
#  'Hoobastank',
#  'a-ha',
#  'Rick Springfield',
#  'Bon Jovi',
#  'Fools Garden',
#  'Bill Withers',
#  'Ella Fitzgerald',
#  'Alanis Morissette',
#  'Mariah Carey',
#  'Fugees',
#  'Bee Gees',
#  'Atomic Kitten',
#  'Mike & The Mechanics',
#  'Redbone',
#  'Lighthouse Family',
#  'Cyndi Lauper',
#  'The Cure',
#  'Shirley Bassey',
#  'Dido',
#  'U2',
#  'Spin Doctors',
#  'Coldplay',
#  'Soft Cell',
#  'Darondo',
#  'Corona',
#  'Rupert Holmes',
#  'Nik Kershaw',
#  'Aretha Franklin',
#  'Joaquín Sabina',
#  'Mungo Jerry',
#  'Joe Cocker',
#  'Ms. Lauryn Hill',
#  'Charles Bradley',
#  'Sade',
#  'Cómplices',
#  'James Brown',
#  'Aerosmith',
#  'Kansas',
#  'Crowded House',
#  'The Monkees',
#  'Charles & Eddie',
#  'Kylie Minogue',
#  'Oasis',
#  'Don McLean',
#  'Wet Wet Wet',
#  'Dire Straits',
#  'Count Basie',
#  'Luther Vandross',
#  'Frank Sinatra',
#  'Fleetwood Mac',
#  'Hot Chocolate',
#  'Richard Marx',
#  'Bonnie Tyler',
#  'Tears For Fears',
#  'Colbie Caillat',
#  'Tom Jones',
#  'Wham!',
#  'Roxy Music',
#  'Chris Isaak',
#  'Madness',
#  'Frankie Valli & The Four Seasons',
#  'The Verve',
#  'Simon & Garfunkel',
#  'Frankie Valli',
#  'Tom Lord-Alge',
#  'All-4-One',
#  'The Cranberries',
#  'George Martin',
#  'Simply Red',
#  'The Beach Boys',
#  'David Gray',
#  'Dean Martin',
#  'Pretenders',
#  'Andy Gibb',
#  'Ace of Base',
#  'No Doubt',
#  'Prince',
#  'Haddaway',
#  'Eagle-Eye Cherry',
#  'Heatwave',
#  'Lifehouse',
#  'Baccara',
#  'The Human League',
#  'Queen',
#  'Blue Swede',
#  'Take That',
#  'Lou Bega',
#  'Big Mountain',
#  'Kool & The Gang',
#  'Spice Girls',
#  'Dexys Midnight Runners',
#  'The Real Thing',
#  'Bruce Springsteen',
#  'Ben Harper',
#  'ABBA',
#  'The Cardigans',
#  'Duffy',
#  'Alexia',
#  'Avril Lavigne',
#  'Al Green',
#  'Bryan Adams',
#  'Earth, Wind & Fire',
#  'Natalie Imbruglia']

# %%
for i in artists_high:
    artist_O.append(i)
    
artist_O
# Out:
# ['Wilson Pickett',
#  "Sinéad O'Connor",
#  'Journey',
#  'Sixpence None The Richer',
#  "Des'ree",
#  'LeAnn Rimes',
#  'Barry Manilow',
#  'Katrina & The Waves',
#  '4 Non Blondes',
#  'Rick Astley',
#  'Lou Reed',
#  'Donna Summer',
#  'The Temptations',
#  'Eagles',
#  'Depeche Mode',
#  'Foreigner',
#  'David Bowie',
#  'Survivor',
#  'Mc Miker "G" & Deejay Sven',
#  'Roy Orbison',
#  'Gabrielle',
#  'Etta James',
#  'Evanescence',
#  'America',
#  'Tammi Terrell',
#  'blink-182',
#  'Creedence Clearwater Revival',
#  'UB40',
#  'Dolly Parton',
#  'Björn Skifs',
#  'The Police',
#  'Heart',
#  'Bobby McFerrin',
#  'Christopher Cross',
#  'Otis Redding',
#  'Neil Diamond',
#  'The Spencer Davis Group',
#  'Percy Sledge',
#  'Daryl Hall & John Oates',
#  'Cheryl Lynn',
#  'Gwen Stefani',
#  'The Rembrandts',
#  'Backstreet Boys',
#  'Elton John',
#  'Tracy Chapman',
#  'Donny Hathaway',
#  'Jimmy Cliff',
#  'Ronan Keating',
#  'Commodores',
#  'Barry White',
#  'Texas',
#  'Elvin Bishop',
#  'Sam & Dave',
#  'Chicago',
#  'Jack Joseph Puig',
#  'MC Hammer',
#  'The Righteous Brothers',
#  'Solomon Burke',
#  'Van Morrison',
#  'Harry Nilsson',
#  'Paul Simon',
#  'The Isley Brothers',
#  'Cher',
#  'Whitney Houston',
#  'New Radicals',
#  'Nina Simone',
#  '3 Doors Down',
#  'Inner Circle',
#  'Billy Paul',
#  'Curtis Mayfield',
#  'Eminem',
#  'Scorpions',
#  'Bap Kennedy',
#  'Billy Joel',
#  'Akon',
#  'Boney M.',
#  'Four Tops',
#  'Air Supply',
#  'Berlin',
#  'Bobby Hebb',
#  'Rod Stewart',
#  'Marvin Gaye',
#  'Shania Twain',
#  'Sting',
#  "The O'Jays",
#  'Yazoo',
#  'Billie Holiday',
#  'The Five Stairsteps',
#  'Kiki Dee',
#  'Yusuf / Cat Stevens',
#  'Sam Cooke',
#  'Suzanne Vega',
#  'Louis Armstrong',
#  'Stevie Wonder',
#  'George Michael',
#  'Extreme',
#  'TLC',
#  'Philip Bailey',
#  'Phil Collins',
#  'Lionel Richie',
#  'Domenico Modugno',
#  'King Harvest',
#  'Paul McCartney',
#  'Counting Crows',
#  'Alphaville',
#  'Savage Garden',
#  'The Proclaimers',
#  'Fergie',
#  'The Spinners',
#  'Kim Carnes',
#  'The Jackson 5',
#  'The Supremes',
#  'Hoobastank',
#  'a-ha',
#  'Rick Springfield',
#  'Bon Jovi',
#  'Fools Garden',
#  'Bill Withers',
#  'Ella Fitzgerald',
#  'Alanis Morissette',
#  'Mariah Carey',
#  'Fugees',
#  'Bee Gees',
#  'Atomic Kitten',
#  'Mike & The Mechanics',
#  'Redbone',
#  'Lighthouse Family',
#  'Cyndi Lauper',
#  'The Cure',
#  'Shirley Bassey',
#  'Dido',
#  'U2',
#  'Spin Doctors',
#  'Coldplay',
#  'Soft Cell',
#  'Darondo',
#  'Corona',
#  'Rupert Holmes',
#  'Nik Kershaw',
#  'Aretha Franklin',
#  'Joaquín Sabina',
#  'Mungo Jerry',
#  'Joe Cocker',
#  'Ms. Lauryn Hill',
#  'Charles Bradley',
#  'Sade',
#  'Cómplices',
#  'James Brown',
#  'Aerosmith',
#  'Kansas',
#  'Crowded House',
#  'The Monkees',
#  'Charles & Eddie',
#  'Kylie Minogue',
#  'Oasis',
#  'Don McLean',
#  'Wet Wet Wet',
#  'Dire Straits',
#  'Count Basie',
#  'Luther Vandross',
#  'Frank Sinatra',
#  'Fleetwood Mac',
#  'Hot Chocolate',
#  'Richard Marx',
#  'Bonnie Tyler',
#  'Tears For Fears',
#  'Colbie Caillat',
#  'Tom Jones',
#  'Wham!',
#  'Roxy Music',
#  'Chris Isaak',
#  'Madness',
#  'Frankie Valli & The Four Seasons',
#  'The Verve',
#  'Simon & Garfunkel',
#  'Frankie Valli',
#  'Tom Lord-Alge',
#  'All-4-One',
#  'The Cranberries',
#  'George Martin',
#  'Simply Red',
#  'The Beach Boys',
#  'David Gray',
#  'Dean Martin',
#  'Pretenders',
#  'Andy Gibb',
#  'Ace of Base',
#  'No Doubt',
#  'Prince',
#  'Haddaway',
#  'Eagle-Eye Cherry',
#  'Heatwave',
#  'Lifehouse',
#  'Baccara',
#  'The Human League',
#  'Queen',
#  'Blue Swede',
#  'Take That',
#  'Lou Bega',
#  'Big Mountain',
#  'Kool & The Gang',
#  'Spice Girls',
#  'Dexys Midnight Runners',
#  'The Real Thing',
#  'Bruce Springsteen',
#  'Ben Harper',
#  'ABBA',
#  'The Cardigans',
#  'Duffy',
#  'Alexia',
#  'Avril Lavigne',
#  'Al Green',
#  'Bryan Adams',
#  'Earth, Wind & Fire',
#  'Natalie Imbruglia',
#  'Radio Stars',
#  "Sinéad O'Connor",
#  'The Golden Filter',
#  'Omar Apollo',
#  "Satan's Rats",
#  'David Bowie',
#  'Kaleta & Super Yamba Band',
#  'Way Yes',
#  'Holy Ghost!',
#  'The Men',
#  'Tim and Foty',
#  'Raekwon',
#  'Ann Peebles',
#  'El Freaky',
#  'John Moods',
#  'Sun Ra',
#  'Los Tones',
#  'Rikki Ililonga',
#  'Durand Jones & The Indications',
#  'TEYMORI',
#  'Otis Brown',
#  'Piero Umiliani',
#  'Grapetooth',
#  'Mathis Hunter',
#  'Sonny Rollins',
#  'Yvonne Fair',
#  'Silk Rhodes',
#  'Dexter Lee Moore',
#  'Nick Drake',
#  'Lea Lea',
#  'Bad Brains',
#  'Empire ISIS',
#  'WITCH',
#  'Stiff Little Fingers',
#  'Nina Simone',
#  'Ptaf',
#  'Dillinger',
#  'Janet Jackson',
#  'De Lux',
#  'U-God',
#  'Serguei',
#  'Impala Syndrome',
#  'Manzanita y su Conjunto',
#  'Talking Heads',
#  'The Roots',
#  'Marvin Gaye',
#  'Sylvester',
#  'Blondie',
#  'Mavis John',
#  'Ghostface Killah',
#  'MUNYA',
#  'Heavy Trash',
#  'Ras Jahonnan',
#  'The Makers',
#  'Denise Darlington',
#  'Ebo Taylor',
#  'Ike & Tina Turner',
#  'Stevie Wonder',
#  'Ronnie Taylor',
#  'The Notorious B.I.G.',
#  'Jitwam',
#  'Kluentah',
#  '!!!',
#  'Bill Withers',
#  'Bosko',
#  'Clarence Murray',
#  'Geoffrey Landers',
#  'Betty Davis',
#  'The Beta Band',
#  'Swamp Dogg',
#  'William Onyeabor',
#  'Soft Cell',
#  'Cheap Trick',
#  'Darondo',
#  'Kantata',
#  'Aretha Franklin',
#  'Aura',
#  'A Tribe Called Quest',
#  'Gabriella Cohen',
#  'Beastie Boys',
#  'Sam Dees',
#  'Double Tiger',
#  'Circle Jerks',
#  'Reginald Omas Mamode IV',
#  'ESG',
#  'Luther Vandross',
#  'Fleetwood Mac',
#  'Cobra Man',
#  'Hailu Mergia',
#  'Os Mutantes',
#  'Jesus Wayne',
#  'Y La Bamba',
#  'Outkast',
#  'Death',
#  'The Equatics',
#  'Céline Dion',
#  'Funkadelic',
#  'World Brain',
#  'Dahlak Band',
#  'Ho99o9',
#  'Jimi Hendrix',
#  "Ronnie D'Addario",
#  'Kevin Rowland',
#  'Grateful Dead',
#  'Tariq Trotter',
#  'Minor Threat',
#  'Direct Drive',
#  'Dead Kennedys',
#  'Ted Lucas',
#  'Bango',
#  'The Pointer Sisters',
#  'Erykah Badu',
#  'Prince',
#  'GBH',
#  'Le1f',
#  'Boyz II Men',
#  'Barbara Stant',
#  'Frank Zappa',
#  'U.S. 69',
#  'Dexys Midnight Runners',
#  'Thomas Doherty',
#  'BOYTOY',
#  'Frank Ocean',
#  'Miho Hatori',
#  'The Replacements',
#  'Blackalicious',
#  'Eve',
#  'Minnie Riperton',
#  'Lula Côrtes',
#  'Lescop',
#  'Lena Platonos',
#  'Lynn Williams',
#  'Wings']

# %%
artists = artist_O

# %%
def get_audio_features(artist):
    # get tracks from artist
    results = sp.search(q=f'artist:{artist}', limit=50)
    # extract the track ids
    track_ids = [track['id'] for track in results['tracks']['items']]
    song_names = [track['name'] for track in results['tracks']['items']]
    # extract the audio features
    audio_features = sp.audio_features(track_ids)
    # store audio features in a dataframe
    df = pd.DataFrame(audio_features)
    df['artist'] = artist
    df['song name'] = song_names
    return df

# %%
df = pd.DataFrame()

for artist in artists:
    try:
        print (artist)
        df_artist = get_audio_features(artist)
        df = pd.concat([df, df_artist])
    except:
        continue
df = df.reset_index(drop=True)

df
# Out:
# Wilson Pickett
# Sinéad O'Connor
# Journey
# Sixpence None The Richer
# Des'ree
# LeAnn Rimes
# Barry Manilow
# Katrina & The Waves
# 4 Non Blondes
# Rick Astley
# Lou Reed
# Donna Summer
# The Temptations
# Eagles
# Depeche Mode
# Foreigner
# David Bowie
# Survivor
# Mc Miker "G" & Deejay Sven
# Roy Orbison
# Gabrielle
# Etta James
# Evanescence
# America
# Tammi Terrell
# blink-182
# Creedence Clearwater Revival
# UB40
# Dolly Parton
# Björn Skifs
# The Police
# Heart
# Bobby McFerrin
# Christopher Cross
# Otis Redding
# Neil Diamond
# The Spencer Davis Group
# Percy Sledge
# Daryl Hall & John Oates
# Cheryl Lynn
# Gwen Stefani
# The Rembrandts
# Backstreet Boys
# Elton John
# Tracy Chapman
# Donny Hathaway
# Jimmy Cliff
# Ronan Keating
# Commodores
# Barry White
# Texas
# Elvin Bishop
# Sam & Dave
# Chicago
# Jack Joseph Puig
# MC Hammer
# The Righteous Brothers
# Solomon Burke
# Van Morrison
# Harry Nilsson
# Paul Simon
# The Isley Brothers
# Cher
# Whitney Houston
# New Radicals
# Nina Simone
# 3 Doors Down
# Inner Circle
# Billy Paul
# Curtis Mayfield
# Eminem
# Scorpions
# Bap Kennedy
# Billy Joel
# Akon
# Boney M.
# Four Tops
# Air Supply
# Berlin
# Bobby Hebb
# Rod Stewart
# Marvin Gaye
# Shania Twain
# Sting
# The O'Jays
# Yazoo
# Billie Holiday
# The Five Stairsteps
# Kiki Dee
# Yusuf / Cat Stevens
# Sam Cooke
# Suzanne Vega
# Louis Armstrong
# Stevie Wonder
# George Michael
# Extreme
# TLC
# Philip Bailey
# Phil Collins
# Lionel Richie
# Domenico Modugno
# King Harvest
# Paul McCartney
# Counting Crows
# Alphaville
# Savage Garden
# The Proclaimers
# Fergie
# The Spinners
# Kim Carnes
# The Jackson 5
# The Supremes
# Hoobastank
# a-ha
# Rick Springfield
# Bon Jovi
# Fools Garden
# Bill Withers
# Ella Fitzgerald
# Alanis Morissette
# Mariah Carey
# Fugees
# Bee Gees
# Atomic Kitten
# Mike & The Mechanics
# Redbone
# Lighthouse Family
# Cyndi Lauper
# The Cure
# Shirley Bassey
# Dido
# U2
# Spin Doctors
# Coldplay
# Soft Cell
# Darondo
# Corona
# Rupert Holmes
# Nik Kershaw
# Aretha Franklin
# Joaquín Sabina
# Mungo Jerry
# Joe Cocker
# Ms. Lauryn Hill
# Charles Bradley
# Sade
# Cómplices
# James Brown
# Aerosmith
# Kansas
# Crowded House
# The Monkees
# Charles & Eddie
# Kylie Minogue
# Oasis
# Don McLean
# Wet Wet Wet
# Dire Straits
# Count Basie
# Luther Vandross
# Frank Sinatra
# Fleetwood Mac
# Hot Chocolate
# Richard Marx
# Bonnie Tyler
# Tears For Fears
# Colbie Caillat
# Tom Jones
# Wham!
# Roxy Music
# Chris Isaak
# Madness
# Frankie Valli & The Four Seasons
# The Verve
# Simon & Garfunkel
# Frankie Valli
# Tom Lord-Alge
# All-4-One
# The Cranberries
# George Martin
# Simply Red
# The Beach Boys
# David Gray
# Dean Martin
# Pretenders
# Andy Gibb
# Ace of Base
# No Doubt
# Prince
# Haddaway
# Eagle-Eye Cherry
# Heatwave
# Lifehouse
# Baccara
# The Human League
# Queen
# Blue Swede
# Take That
# Lou Bega
# Big Mountain
# Kool & The Gang
# Spice Girls
# Dexys Midnight Runners
# The Real Thing
# Bruce Springsteen
# Ben Harper
# ABBA
# The Cardigans
# Duffy
# Alexia
# Avril Lavigne
# Al Green
# Bryan Adams
# Earth, Wind & Fire
# Natalie Imbruglia
# Radio Stars
# Sinéad O'Connor
# The Golden Filter
# Omar Apollo
# Satan's Rats
# David Bowie
# Kaleta & Super Yamba Band
# Way Yes
# Holy Ghost!
# The Men
# Tim and Foty
# Raekwon
# Ann Peebles
# El Freaky
# John Moods
# Sun Ra
# Los Tones
# Rikki Ililonga
# Durand Jones & The Indications
# TEYMORI
# Otis Brown
# Piero Umiliani
# Grapetooth
# Mathis Hunter
# Sonny Rollins
# Yvonne Fair
# Silk Rhodes
# Dexter Lee Moore
# Nick Drake
# Lea Lea
# Bad Brains
# Empire ISIS
# WITCH
# Stiff Little Fingers
# Nina Simone
# Ptaf
# Dillinger
# Janet Jackson
# De Lux
# U-God
# Serguei
# Impala Syndrome
# Manzanita y su Conjunto
# Talking Heads
# The Roots
# Marvin Gaye
# Sylvester
# Blondie
# Mavis John
# Ghostface Killah
# MUNYA
# Heavy Trash
# Ras Jahonnan
# The Makers
# Denise Darlington
# Ebo Taylor
# Ike & Tina Turner
# Stevie Wonder
# Ronnie Taylor
# The Notorious B.I.G.
# Jitwam
# Kluentah
# !!!
# Bill Withers
# Bosko
# Clarence Murray
# Geoffrey Landers
# Betty Davis
# The Beta Band
# Swamp Dogg
# William Onyeabor
# Soft Cell
# Cheap Trick
# Darondo
# Kantata
# Aretha Franklin
# Aura
# A Tribe Called Quest
# Gabriella Cohen
# Beastie Boys
# Sam Dees
# Double Tiger
# Circle Jerks
# Reginald Omas Mamode IV
# ESG
# Luther Vandross
# Fleetwood Mac
# Cobra Man
# Hailu Mergia
# Os Mutantes
# Jesus Wayne
# Y La Bamba
# Outkast
# Death
# The Equatics
# Céline Dion
# Funkadelic
# World Brain
# Dahlak Band
# Ho99o9
# Jimi Hendrix
# Ronnie D'Addario
# Kevin Rowland
# Grateful Dead
# Tariq Trotter
# Minor Threat
# Direct Drive
# Dead Kennedys
# Ted Lucas
# Bango
# The Pointer Sisters
# Erykah Badu
# Prince
# GBH
# Le1f
# Boyz II Men
# Barbara Stant
# Frank Zappa
# U.S. 69
# Dexys Midnight Runners
# Thomas Doherty
# BOYTOY
# Frank Ocean
# Miho Hatori
# The Replacements
# Blackalicious
# Eve
# Minnie Riperton
# Lula Côrtes
# Lescop
# Lena Platonos
# Lynn Williams
# Wings
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.725   0.327    0   -17.714     1       0.0387        0.1130
# 1             0.618   0.588    2   -11.624     1       0.0735        0.0128
# 2             0.750   0.444    4    -8.630     1       0.0403        0.1200
# 3             0.561   0.385    6   -15.330     1       0.0323        0.1460
# 4             0.760   0.522    0    -8.088     1       0.0348        0.0906
# ...             ...     ...  ...       ...   ...          ...           ...
# 15971         0.472   0.736    7   -10.208     1       0.1110        0.4080
# 15972         0.514   0.363    2    -9.400     1       0.0270        0.5290
# 15973         0.481   0.645    7    -7.609     1       0.0335        0.0864
# 15974         0.741   0.535    1   -15.884     0       0.0439        0.2070
# 15975         0.366   0.854    2    -6.100     1       0.0833        0.0847
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.326000     0.214    0.688  110.438  audio_features
# 1              0.026600     0.351    0.768   86.903  audio_features
# 2              0.000004     0.118    0.849  111.919  audio_features
# 3              0.000496     0.171    0.664   81.599  audio_features
# 4              0.000003     0.174    0.551  109.741  audio_features
# ...                 ...       ...      ...      ...             ...
# 15971          0.000000     0.970    0.559  119.538  audio_features
# 15972          0.000848     0.586    0.494   78.268  audio_features
# 15973          0.000005     0.336    0.518  113.024  audio_features
# 15974          0.002340     0.147    0.943  123.331  audio_features
# 15975          0.000670     0.635    0.593  132.725  audio_features
#
#                            id                                   uri  \
# 0      5Sz09kaSzvpTC8lgm5W8Mt  spotify:track:5Sz09kaSzvpTC8lgm5W8Mt
# 1      76ICmoJ4PcoMWoooaTxnQs  spotify:track:76ICmoJ4PcoMWoooaTxnQs
# 2      4NRQwaks9r58tTDvr4iEyv  spotify:track:4NRQwaks9r58tTDvr4iEyv
# 3      1MMp1H2Kib2BCDtdL5nL63  spotify:track:1MMp1H2Kib2BCDtdL5nL63
# 4      7mRak6wBx9OGKXr3zStoHW  spotify:track:7mRak6wBx9OGKXr3zStoHW
# ...                       ...                                   ...
# 15971  5NQdAm6jRqZa3mBdtHEfXO  spotify:track:5NQdAm6jRqZa3mBdtHEfXO
# 15972  1hVl3NtSqi6LXZ7pXxHPrC  spotify:track:1hVl3NtSqi6LXZ7pXxHPrC
# 15973  3hFYMKAolw99FZMXEGgGwv  spotify:track:3hFYMKAolw99FZMXEGgGwv
# 15974  6mDouoIwwH5Pjbx1KUhXIB  spotify:track:6mDouoIwwH5Pjbx1KUhXIB
# 15975  5d2aKTwOLjNt0I7DheWyVv  spotify:track:5d2aKTwOLjNt0I7DheWyVv
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/5Sz09kaSzvpT...
# 1      https://api.spotify.com/v1/tracks/76ICmoJ4PcoM...
# 2      https://api.spotify.com/v1/tracks/4NRQwaks9r58...
# 3      https://api.spotify.com/v1/tracks/1MMp1H2Kib2B...
# 4      https://api.spotify.com/v1/tracks/7mRak6wBx9OG...
# ...                                                  ...
# 15971  https://api.spotify.com/v1/tracks/5NQdAm6jRqZa...
# 15972  https://api.spotify.com/v1/tracks/1hVl3NtSqi6L...
# 15973  https://api.spotify.com/v1/tracks/3hFYMKAolw99...
# 15974  https://api.spotify.com/v1/tracks/6mDouoIwwH5P...
# 15975  https://api.spotify.com/v1/tracks/5d2aKTwOLjNt...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/5Sz0...       187760
# 1      https://api.spotify.com/v1/audio-analysis/76IC...       146973
# 2      https://api.spotify.com/v1/audio-analysis/4NRQ...       157160
# 3      https://api.spotify.com/v1/audio-analysis/1MMp...       247733
# 4      https://api.spotify.com/v1/audio-analysis/7mRa...       187827
# ...                                                  ...          ...
# 15971  https://api.spotify.com/v1/audio-analysis/5NQd...       130000
# 15972  https://api.spotify.com/v1/audio-analysis/1hVl...        78800
# 15973  https://api.spotify.com/v1/audio-analysis/3hFY...       235360
# 15974  https://api.spotify.com/v1/audio-analysis/6mDo...       259067
# 15975  https://api.spotify.com/v1/audio-analysis/5d2a...       332707
#
#        time_signature          artist  \
# 0                   4  Wilson Pickett
# 1                   4  Wilson Pickett
# 2                   4  Wilson Pickett
# 3                   4  Wilson Pickett
# 4                   4  Wilson Pickett
# ...               ...             ...
# 15971               4           Wings
# 15972               4           Wings
# 15973               4           Wings
# 15974               4           Wings
# 15975               4           Wings
#
#                                        song name
# 0                                  Mustang Sally
# 1                            Land of 1000 Dances
# 2                           In the Midnight Hour
# 3                                       Hey Jude
# 4                                  Mustang Sally
# ...                                          ...
# 15971  I've Just Seen A Face - Live / Remastered
# 15972           Venus And Mars - Remastered 2014
# 15973                Listen To What The Man Said
# 15974                          Goodnight Tonight
# 15975                Rock Show - Remastered 2014
#
# [15976 rows x 20 columns]

# %%
df.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# artist              0
# song name           0
# dtype: int64

# %%
x = df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

# %%
scaler = StandardScaler()

x_prep = scaler.fit_transform(x)

kmeans = KMeans(n_clusters=10, random_state=42)
kmeans.fit(x_prep)

clusters = kmeans.predict(x_prep)

scaled_df = pd.DataFrame(x_prep, columns=x.columns)
scaled_df['song name'] = df['song name']
scaled_df['artist'] = df['artist']
scaled_df['cluster'] = clusters
scaled_df
# Out:
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.900424 -1.202512 -1.460367 -1.992559  0.668068    -0.373041
# 1          0.239124 -0.065561 -0.905195 -0.553799  0.668068     0.027010
# 2          1.054933 -0.692844 -0.350023  0.153533  0.668068    -0.354648
# 3         -0.113157 -0.949856  0.205149 -1.429340  0.668068    -0.446614
# 4          1.116736 -0.353066 -1.460367  0.281580  0.668068    -0.417875
# ...             ...       ...       ...       ...       ...          ...
# 15971     -0.663210  0.579146  0.482735 -0.219269  0.668068     0.458100
# 15972     -0.403635 -1.045691 -0.905195 -0.028380  0.668068    -0.507541
# 15973     -0.607587  0.182738  0.482735  0.394744  0.668068    -0.432819
# 15974      0.999309 -0.296436 -1.182781 -1.560223 -1.496853    -0.313264
# 15975     -1.318329  1.093170 -0.905195  0.751244  0.668068     0.139668
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0         -0.636538          1.034559  0.127989  0.472658 -0.320438
# 1         -0.974456         -0.277706  0.949717  0.787803 -1.149011
# 2         -0.612931         -0.394277 -0.447820  1.106887 -0.268298
# 3         -0.525247         -0.392119 -0.129925  0.378114 -1.335743
# 4         -0.712080         -0.394278 -0.111931 -0.067027 -0.344977
# ...             ...               ...       ...       ...       ...
# 15971      0.358332         -0.394293  4.662485 -0.035513 -0.000064
# 15972      0.766397         -0.390576  2.359249 -0.291568 -1.453014
# 15973     -0.726245         -0.394271  0.859746 -0.197025 -0.229396
# 15974     -0.319528         -0.384037 -0.273878  1.477182  0.133472
# 15975     -0.731978         -0.391356  2.653152  0.098424  0.464197
#
#                                        song name          artist  cluster
# 0                                  Mustang Sally  Wilson Pickett        1
# 1                            Land of 1000 Dances  Wilson Pickett        1
# 2                           In the Midnight Hour  Wilson Pickett        1
# 3                                       Hey Jude  Wilson Pickett        6
# 4                                  Mustang Sally  Wilson Pickett        1
# ...                                          ...             ...      ...
# 15971  I've Just Seen A Face - Live / Remastered           Wings        3
# 15972           Venus And Mars - Remastered 2014           Wings        3
# 15973                Listen To What The Man Said           Wings        8
# 15974                          Goodnight Tonight           Wings        2
# 15975                Rock Show - Remastered 2014           Wings        3
#
# [15976 rows x 14 columns]

# %%
scaled_df.groupby(['cluster', 'artist'], as_index=False).count().sort_values(['cluster', 'key'], ascending=[True, False])[['artist', 'cluster', 'key']].reset_index(drop=True)
# Out:
#                 artist  cluster  key
# 0        Dead Kennedys        0   28
# 1        Avril Lavigne        0   27
# 2           Hoobastank        0   26
# 3         Minor Threat        0   24
# 4                  GBH        0   23
# ...                ...      ...  ...
# 2358    Thomas Doherty        9    1
# 2359  William Onyeabor        9    1
# 2360    Wilson Pickett        9    1
# 2361        Y La Bamba        9    1
# 2362             Yazoo        9    1
#
# [2363 rows x 3 columns]

# %%
def recommend_song():
    # get song id
    song_name = input('Choose a song: ')
    results = sp.search(q=f'track:{song_name}', limit=1)
    track_id = results['tracks']['items'][0]['id']
    # get song features with the obtained id
    audio_features = sp.audio_features(track_id)
    # create dataframe
    df_ = pd.DataFrame(audio_features)
    new_features = df_[x.columns]
    # scale features
    scaled_x = scaler.transform(new_features)
    # predict cluster
    cluster = kmeans.predict(scaled_x)
    # filter dataset to predicted cluster
    filtered_df = scaled_df[scaled_df['cluster'] == cluster[0]][x.columns]
    # get closest song from filtered dataset
    closest, _ = pairwise_distances_argmin_min(scaled_x, filtered_df)
    # return it in a readable way
    print('\n [RECOMMENDED SONG]')
    return ' - '.join([scaled_df.loc[closest]['song name'].values[0], scaled_df.loc[closest]['artist'].values[0]])

# %%
recommend_song()
